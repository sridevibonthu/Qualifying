# %% [markdown]
# <a href="https://colab.research.google.com/github/sridevibonthu/Qualifying/blob/master/Model_Ravana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !unzip -q "/content/gdrive/My Drive/Assignment5/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D, SeparableConvolution2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, avg_color=np.array([0,0,0])):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        input_img[top:top + h, left:left + w, :] = avg_color

        return input_img

    return eraser

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

# %%
class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, train_mean, train_std, batch_size=32, shuffle=True):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.train_mean = train_mean
        self.train_std = train_std
        #self.val = val
        #self.eraser=get_random_eraser()

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        images = []
        for image in [cv2.imread(item["image_path"]) for _, item in items.iterrows()]:
          # normalize mean of 0 and stdev of 1
          image = ((image-self.train_mean)/self.train_std).astype('float32') 

          #if not self.val:
            #image = self.eraser(image)
            #image = tf.image.random_flip_left_right(image)
          
          images.append(image)

        images = np.stack(images, axis=0)

        #image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        target= {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        
        return images, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.2, random_state=42)
train_df.shape, val_df.shape
# Out:
# ((10858, 28), (2715, 28))

# %%
from tqdm import tnrange, tqdm_notebook
n = 0
s = np.zeros(3)
sq = np.zeros(3)
y = None
for _, item in tqdm_notebook(train_df.iterrows()):
  x = cv2.imread(item["image_path"]).astype('double')
  s += np.sum(x, axis=(0,1))
  sq += np.sum(np.square(x), axis=(0,1))
  n += x.shape[0]*x.shape[1]
  y = x

mu = s/n
std = np.sqrt((sq/n - np.square(mu)))

print(mu, std, n)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# [41.34606735 41.56142807 46.62353164] [63.99020204 64.62708368 69.80721893] 544811008

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, mu, std, batch_size=16)
valid_gen = PersonDataGenerator(val_df, mu, std, batch_size=16, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
def myModel(input_shape=(224,224,3)):
  model=Sequential()
  model.add(Convolution2D(64, (3, 3), padding='same', input_shape=input_shape, name='B1_C1'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Convolution2D(64, (3, 3), padding='same', name='B1_C2'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2),  strides=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Convolution2D(128, (3, 3), padding='same', name='B2_C1'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Convolution2D(128, (3, 3), padding='same', name='B2_C2'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2),  strides=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Convolution2D(256, (3, 3), padding='same',name='B3_C1'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Convolution2D(256, (3, 3), padding='same', name='B3_C2'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2),  strides=(2, 2), name='MP3'))
  model.add(Dropout(0.25))

  model.add(Convolution2D(512, (3, 3), padding='same',name='B4_C1'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Convolution2D(512, (3, 3), padding='same', name='B4_C2'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(Convolution2D(512, (3, 3), padding='same', name='B4_C3'))
  model.add(Activation('relu'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D(pool_size=(2, 2),  strides=(2, 2), name='MP4'))
  model.add(Dropout(0.25))

  

  return model

# %%
backbone = myModel()
backbone.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# B1_C1 (Conv2D)               (None, 224, 224, 64)      1792
# _________________________________________________________________
# activation_1 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 224, 224, 64)      256
# _________________________________________________________________
# B1_C2 (Conv2D)               (None, 224, 224, 64)      36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 224, 224, 64)      0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 224, 224, 64)      256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 112, 112, 64)      0
# _________________________________________________________________
# B2_C1 (Conv2D)               (None, 112, 112, 128)     73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# B2_C2 (Conv2D)               (None, 112, 112, 128)     147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 112, 112, 128)     0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 112, 112, 128)     512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# B3_C1 (Conv2D)               (None, 56, 56, 256)       295168
# _________________________________________________________________
# activation_5 (Activation)    (None, 56, 56, 256)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 56, 56, 256)       1024
# _________________________________________________________________
# B3_C2 (Conv2D)               (None, 56, 56, 256)       590080
# _________________________________________________________________
# activation_6 (Activation)    (None, 56, 56, 256)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 56, 56, 256)       1024
# _________________________________________________________________
# MP3 (MaxPooling2D)           (None, 28, 28, 256)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 28, 28, 256)       0
# _________________________________________________________________
# B4_C1 (Conv2D)               (None, 28, 28, 512)       1180160
# _________________________________________________________________
# activation_7 (Activation)    (None, 28, 28, 512)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 28, 512)       2048
# _________________________________________________________________
# B4_C2 (Conv2D)               (None, 28, 28, 512)       2359808
# _________________________________________________________________
# activation_8 (Activation)    (None, 28, 28, 512)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 28, 28, 512)       2048
# _________________________________________________________________
# B4_C3 (Conv2D)               (None, 28, 28, 512)       2359808
# _________________________________________________________________
# activation_9 (Activation)    (None, 28, 28, 512)       0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 28, 28, 512)       2048
# _________________________________________________________________
# MP4 (MaxPooling2D)           (None, 14, 14, 512)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 14, 14, 512)       0
# =================================================================
# Total params: 7,054,912
# Trainable params: 7,050,048
# Non-trainable params: 4,864
# _________________________________________________________________

# %%
neck=backbone.output
print(neck)
# Out:
# Tensor("dropout_4/cond/Merge:0", shape=(?, 14, 14, 512), dtype=float32)

# %%
def build_tower(in_layer):
  neck = Convolution2D(512, (3,3), padding='same', activation='relu' )(in_layer)
  neck = MaxPooling2D(pool_size=(2, 2),  strides=(2, 2))(neck)
  neck = Convolution2D(512, (7, 7), activation='relu')(neck)
  neck = Flatten()(neck)
  '''
  neck = Dense(512, activation="relu")(neck)
  neck = Dropout(0.2)(neck)
  neck = Dense(128, activation="relu")(neck)
  neck = Dropout(0.3)(neck)
  neck = Dense(128, activation="relu")(neck)'''
  return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))

age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))

bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))

emotion = build_head("emotion", build_tower(neck))

pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

# %%
print(backbone.input)
# Out:
# Tensor("B1_C1_input_4:0", shape=(?, 224, 224, 3), dtype=float32)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# B1_C1_input (InputLayer)        (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# B1_C1 (Conv2D)                  (None, 224, 224, 64) 1792        B1_C1_input[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 64) 0           B1_C1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 64) 256         activation_1[0][0]
# __________________________________________________________________________________________________
# B1_C2 (Conv2D)                  (None, 224, 224, 64) 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 64) 0           B1_C2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 64) 256         activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 112, 112, 64) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# B2_C1 (Conv2D)                  (None, 112, 112, 128 73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 128 0           B2_C1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 128 512         activation_3[0][0]
# __________________________________________________________________________________________________
# B2_C2 (Conv2D)                  (None, 112, 112, 128 147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 128 0           B2_C2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 128 512         activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 56, 56, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# B3_C1 (Conv2D)                  (None, 56, 56, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 256)  0           B3_C1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 256)  1024        activation_5[0][0]
# __________________________________________________________________________________________________
# B3_C2 (Conv2D)                  (None, 56, 56, 256)  590080      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 256)  0           B3_C2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 256)  1024        activation_6[0][0]
# __________________________________________________________________________________________________
# MP3 (MaxPooling2D)              (None, 28, 28, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 28, 28, 256)  0           MP3[0][0]
# __________________________________________________________________________________________________
# B4_C1 (Conv2D)                  (None, 28, 28, 512)  1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 512)  0           B4_C1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 512)  2048        activation_7[0][0]
# __________________________________________________________________________________________________
# B4_C2 (Conv2D)                  (None, 28, 28, 512)  2359808     batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 512)  0           B4_C2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 512)  2048        activation_8[0][0]
# __________________________________________________________________________________________________
# B4_C3 (Conv2D)                  (None, 28, 28, 512)  2359808     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 512)  0           B4_C3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 512)  2048        activation_9[0][0]
# __________________________________________________________________________________________________
# MP4 (MaxPooling2D)              (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 14, 14, 512)  0           MP4[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 512)    0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 512)    0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 512)    12845568    max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 1, 1, 512)    12845568    max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 1, 1, 512)    12845568    max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 1, 1, 512)    12845568    max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 1, 1, 512)    12845568    max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 1, 1, 512)    12845568    max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 512)    12845568    max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 1, 1, 512)    12845568    max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 512)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 512)          0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 512)          0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 512)          0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 512)          0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 512)          0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            1026        flatten_1[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            1539        flatten_2[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            2565        flatten_3[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            2052        flatten_4[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            1539        flatten_5[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            1539        flatten_6[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            1539        flatten_8[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            2052        flatten_7[0][0]
# ==================================================================================================
# Total params: 128,711,771
# Trainable params: 128,706,907
# Non-trainable params: 4,864
# __________________________________________________________________________________________________

# %%
from keras.utils import plot_model
plot_model(model)

# %%
from keras.callbacks import *

class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
clr = CyclicLR(base_lr=0.001, max_lr=0.06, step_size=2000., mode='triangular2')

# %%
opt = SGD(lr=0.001,momentum=0.9)
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=24,
    verbose=1,
      )
# Out:
# Epoch 1/24
# 678/678 [==============================] - 211s 311ms/step - loss: 69.1601 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6816 - weight_output_loss: 12.2773 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6313 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3993 - weight_output_acc: 0.2383 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7127 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 2/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1586 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6771 - weight_output_loss: 12.2758 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6387 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3996 - weight_output_acc: 0.2384 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7122 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
#  - 211s 311ms/step - loss: 69.1601 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6816 - weight_output_loss: 12.2773 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6313 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3993 - weight_output_acc: 0.2383 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7127 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 3/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1735 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6830 - weight_output_loss: 12.2788 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9446 - pose_output_loss: 6.1423 - emotion_output_loss: 4.6387 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3992 - weight_output_acc: 0.2382 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4451 - pose_output_acc: 0.6189 - emotion_output_acc: 0.7122 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 3/24Epoch 4/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1453 - gender_output_loss: 7.0056 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6786 - weight_output_loss: 12.2728 - bag_output_loss: 7.0190 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1468 - emotion_output_loss: 4.6298 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3995 - weight_output_acc: 0.2386 - bag_output_acc: 0.5645 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7128 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 4/24
# Epoch 5/24
# 677/678 [============================>.] - ETA: 0s - loss: 69.1656 - gender_output_loss: 7.0085 - image_quality_output_loss: 13.4575 - age_output_loss: 9.6840 - weight_output_loss: 12.2731 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9399 - pose_output_loss: 6.1455 - emotion_output_loss: 4.6337 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1651 - age_output_acc: 0.3992 - weight_output_acc: 0.2386 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7125Epoch 5/24
# 678/678 [==============================] - 204s 300ms/step - loss: 69.1571 - gender_output_loss: 7.0071 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6816 - weight_output_loss: 12.2758 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1423 - emotion_output_loss: 4.6372 - gender_output_acc: 0.5653 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3993 - weight_output_acc: 0.2384 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6189 - emotion_output_acc: 0.7123 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 6/24
# 677/678 [============================>.] - ETA: 0s - loss: 69.1551 - gender_output_loss: 7.0115 - image_quality_output_loss: 13.4501 - age_output_loss: 9.6750 - weight_output_loss: 12.2761 - bag_output_loss: 7.0219 - footwear_output_loss: 8.9504 - pose_output_loss: 6.1425 - emotion_output_loss: 4.6277 - gender_output_acc: 0.5650 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3997 - weight_output_acc: 0.2384 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4447 - pose_output_acc: 0.6189 - emotion_output_acc: 0.7129
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1571 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6756 - weight_output_loss: 12.2758 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9446 - pose_output_loss: 6.1468 - emotion_output_loss: 4.6298 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3997 - weight_output_acc: 0.2384 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4451 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7128 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 7/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1542 - gender_output_loss: 7.0056 - image_quality_output_loss: 13.4511 - age_output_loss: 9.6771 - weight_output_loss: 12.2758 - bag_output_loss: 7.0249 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3996 - weight_output_acc: 0.2384 - bag_output_acc: 0.5642 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 8/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1557 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4511 - age_output_loss: 9.6786 - weight_output_loss: 12.2743 - bag_output_loss: 7.0220 - footwear_output_loss: 8.9416 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3995 - weight_output_acc: 0.2385 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 9/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1705 - gender_output_loss: 7.0071 - image_quality_output_loss: 13.4570 - age_output_loss: 9.6845 - weight_output_loss: 12.2773 - bag_output_loss: 7.0220 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1498 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5653 - image_quality_output_acc: 0.1651 - age_output_acc: 0.3992 - weight_output_acc: 0.2383 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 10/24
# 677/678 [============================>.] - ETA: 0s - loss: 69.1670 - gender_output_loss: 7.0100 - image_quality_output_loss: 13.4501 - age_output_loss: 9.6854 - weight_output_loss: 12.2731 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9429 - pose_output_loss: 6.1455 - emotion_output_loss: 4.6366 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3991 - weight_output_acc: 0.2386 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7123
# 678/678 [==============================] - 204s 300ms/step - loss: 69.1661 - gender_output_loss: 7.0145 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6816 - weight_output_loss: 12.2743 - bag_output_loss: 7.0249 - footwear_output_loss: 8.9416 - pose_output_loss: 6.1438 - emotion_output_loss: 4.6357 - gender_output_acc: 0.5648 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3993 - weight_output_acc: 0.2385 - bag_output_acc: 0.5642 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6188 - emotion_output_acc: 0.7124 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 11/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1571 - gender_output_loss: 7.0115 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6786 - weight_output_loss: 12.2773 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6328 - gender_output_acc: 0.5650 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3995 - weight_output_acc: 0.2383 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7126 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 12/24
# 678/678 [==============================] - 202s 298ms/step - loss: 69.1571 - gender_output_loss: 7.0071 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6771 - weight_output_loss: 12.2758 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9372 - pose_output_loss: 6.1498 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5653 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3996 - weight_output_acc: 0.2384 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4455 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 13/24
# Epoch 12/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1542 - gender_output_loss: 7.0056 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6756 - weight_output_loss: 12.2743 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9416 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6372 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3997 - weight_output_acc: 0.2385 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7123 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 14/24
# Epoch 13/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1631 - gender_output_loss: 7.0101 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6830 - weight_output_loss: 12.2758 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1468 - emotion_output_loss: 4.6372 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3992 - weight_output_acc: 0.2384 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7123 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 15/24
# 677/678 [============================>.] - ETA: 0s - loss: 69.1730 - gender_output_loss: 7.0055 - image_quality_output_loss: 13.4575 - age_output_loss: 9.6720 - weight_output_loss: 12.2805 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9459 - pose_output_loss: 6.1514 - emotion_output_loss: 4.6366 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1651 - age_output_acc: 0.3999 - weight_output_acc: 0.2381 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4450 - pose_output_acc: 0.6184 - emotion_output_acc: 0.7123Epoch 15/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1557 - gender_output_loss: 7.0041 - image_quality_output_loss: 13.4570 - age_output_loss: 9.6741 - weight_output_loss: 12.2773 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9416 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6328 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1651 - age_output_acc: 0.3998 - weight_output_acc: 0.2383 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7126 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 16/24
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1616 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6741 - weight_output_loss: 12.2802 - bag_output_loss: 7.0220 - footwear_output_loss: 8.9431 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6313 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3998 - weight_output_acc: 0.2381 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7127 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 17/24
# 678/678 [==============================] - 203s 300ms/step - loss: 69.1616 - gender_output_loss: 7.0101 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6801 - weight_output_loss: 12.2758 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1498 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3994 - weight_output_acc: 0.2384 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# 678/678 [==============================] - 203s 299ms/step - loss: 69.1616 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6741 - weight_output_loss: 12.2802 - bag_output_loss: 7.0220 - footwear_output_loss: 8.9431 - pose_output_loss: 6.1483 - emotion_output_loss: 4.6313 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3998 - weight_output_acc: 0.2381 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7127 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 18/24
# 678/678 [==============================] - 202s 299ms/step - loss: 69.1512 - gender_output_loss: 7.0056 - image_quality_output_loss: 13.4511 - age_output_loss: 9.6801 - weight_output_loss: 12.2773 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1438 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3994 - weight_output_acc: 0.2383 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6188 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 19/24
# 678/678 [==============================] - 201s 297ms/step - loss: 69.1631 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4511 - age_output_loss: 9.6801 - weight_output_loss: 12.2743 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9431 - pose_output_loss: 6.1498 - emotion_output_loss: 4.6357 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3994 - weight_output_acc: 0.2385 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7124 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# 678/678 [==============================] - 202s 299ms/step - loss: 69.1512 - gender_output_loss: 7.0056 - image_quality_output_loss: 13.4511 - age_output_loss: 9.6801 - weight_output_loss: 12.2773 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1438 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1655 - age_output_acc: 0.3994 - weight_output_acc: 0.2383 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6188 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
#
# Epoch 20/24
# 677/678 [============================>.] - ETA: 0s - loss: 69.1477 - gender_output_loss: 7.0041 - image_quality_output_loss: 13.4486 - age_output_loss: 9.6750 - weight_output_loss: 12.2761 - bag_output_loss: 7.0160 - footwear_output_loss: 8.9399 - pose_output_loss: 6.1499 - emotion_output_loss: 4.6381 - gender_output_acc: 0.5655 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3997 - weight_output_acc: 0.2384 - bag_output_acc: 0.5647 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6184 - emotion_output_acc: 0.7122Epoch 20/24
# 678/678 [==============================] - 201s 296ms/step - loss: 69.1542 - gender_output_loss: 7.0041 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6771 - weight_output_loss: 12.2743 - bag_output_loss: 7.0175 - footwear_output_loss: 8.9431 - pose_output_loss: 6.1498 - emotion_output_loss: 4.6357 - gender_output_acc: 0.5654 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3996 - weight_output_acc: 0.2385 - bag_output_acc: 0.5646 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6185 - emotion_output_acc: 0.7124 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 21/24
# 678/678 [==============================] - 201s 297ms/step - loss: 69.1661 - gender_output_loss: 7.0115 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6771 - weight_output_loss: 12.2773 - bag_output_loss: 7.0234 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1468 - emotion_output_loss: 4.6372 - gender_output_acc: 0.5650 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3996 - weight_output_acc: 0.2383 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7123 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 21/24
# Epoch 22/24
# Epoch 22/24
# 678/678 [==============================] - 200s 295ms/step - loss: 69.1542 - gender_output_loss: 7.0086 - image_quality_output_loss: 13.4525 - age_output_loss: 9.6756 - weight_output_loss: 12.2802 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9386 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6328 - gender_output_acc: 0.5652 - image_quality_output_acc: 0.1654 - age_output_acc: 0.3997 - weight_output_acc: 0.2381 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4454 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7126 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 23/24
# 678/678 [==============================] - 201s 297ms/step - loss: 69.1661 - gender_output_loss: 7.0130 - image_quality_output_loss: 13.4496 - age_output_loss: 9.6816 - weight_output_loss: 12.2758 - bag_output_loss: 7.0220 - footwear_output_loss: 8.9431 - pose_output_loss: 6.1468 - emotion_output_loss: 4.6342 - gender_output_acc: 0.5649 - image_quality_output_acc: 0.1656 - age_output_acc: 0.3993 - weight_output_acc: 0.2384 - bag_output_acc: 0.5643 - footwear_output_acc: 0.4452 - pose_output_acc: 0.6186 - emotion_output_acc: 0.7125 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075
# Epoch 24/24
# 678/678 [==============================] - 200s 296ms/step - loss: 69.1646 - gender_output_loss: 7.0101 - image_quality_output_loss: 13.4540 - age_output_loss: 9.6801 - weight_output_loss: 12.2758 - bag_output_loss: 7.0205 - footwear_output_loss: 8.9401 - pose_output_loss: 6.1453 - emotion_output_loss: 4.6387 - gender_output_acc: 0.5651 - image_quality_output_acc: 0.1653 - age_output_acc: 0.3994 - weight_output_acc: 0.2384 - bag_output_acc: 0.5644 - footwear_output_acc: 0.4453 - pose_output_acc: 0.6187 - emotion_output_acc: 0.7122 - val_loss: 69.9623 - val_gender_output_loss: 7.2186 - val_image_quality_output_loss: 13.4774 - val_age_output_loss: 9.7460 - val_weight_output_loss: 12.5237 - val_bag_output_loss: 7.0934 - val_footwear_output_loss: 8.9711 - val_pose_output_loss: 6.2171 - val_emotion_output_loss: 4.7150 - val_gender_output_acc: 0.5521 - val_image_quality_output_acc: 0.1638 - val_age_output_acc: 0.3953 - val_weight_output_acc: 0.2230 - val_bag_output_acc: 0.5599 - val_footwear_output_acc: 0.4434 - val_pose_output_acc: 0.6143 - val_emotion_output_acc: 0.7075

# %%
history=model.history

# %%
#print(history.history.keys())
for x in history.history.keys():
  if x.startswith('val') and x.endswith('acc'):
    print(x, " -- ",  history.history[x][-1])
# Out:
# val_gender_output_acc  --  0.5521449704142012
# val_image_quality_output_acc  --  0.16383136094674555
# val_age_output_acc  --  0.3953402366863905
# val_weight_output_acc  --  0.22300295857988164
# val_bag_output_acc  --  0.5599112426035503
# val_footwear_output_acc  --  0.4434171597633136
# val_pose_output_acc  --  0.6142751479289941
# val_emotion_output_acc  --  0.7074704142011834

# %%
print('gender : ', max(history.history['val_gender_output_acc']))
print('image quality : ', max(history.history['val_image_quality_output_acc']))
print('age : ', max(history.history['val_age_output_acc']))
print('weight : ', max(history.history['val_weight_output_acc']))
print('bag : ', max(history.history['val_bag_output_acc']))
print('footwear : ', max(history.history['val_footwear_output_acc']))
print('pose : ', max(history.history['val_pose_output_acc']))
print('emotion : ', max(history.history['val_emotion_output_acc']))
# Out:
# gender :  0.5521449704142012
# image quality :  0.16383136094674555
# age :  0.3953402366863905
# weight :  0.22300295857988164
# bag :  0.5599112426035503
# footwear :  0.4434171597633136
# pose :  0.6142751479289941
# emotion :  0.7074704142011834

# %%
history=model.history

# %%
val_loss=[]
for i in range(24):
  sum=0
  l = ['val_gender_output_loss','val_image_quality_output_loss',  'val_age_output_loss', 'val_weight_output_loss', 'val_bag_output_loss', 'val_footwear_output_loss', 'val_pose_output_loss',
 'val_emotion_output_loss']
  for x in l:
    sum += history.history[x][i]
  val_loss.append(sum)
print(val_loss)
# Out:
# [69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066, 69.96231007717066]

# %%
  import matplotlib.pyplot as plt
  plt.plot(history.history['loss'])
  plt.plot(val_loss)
  plt.title('model loss')
  plt.ylabel('loss')
  plt.xlabel('epoch')
  plt.legend(['train', 'validation'], loc='upper left')
  plt.show()  #no reduction in validation loss

# %%
plt.plot(history.history['val_gender_output_acc'])
plt.plot(history.history['val_image_quality_output_acc'])
plt.plot(history.history['val_age_output_acc'])
plt.plot(history.history['val_weight_output_acc'])
plt.plot(history.history['val_bag_output_acc'])
plt.plot(history.history['val_footwear_output_acc'])
plt.plot(history.history['val_pose_output_acc'])
plt.plot(history.history['val_emotion_output_acc'])
plt.legend(['gender', 'imgquality','age','weight', 'bag','fw','pose','e'], loc='upper left')
plt.show()
